# %% [markdown]
# # This is SmallTrain v0.2.1 Demo for image detection
# # You can get v0.2.1 on https://github.com/geek-guild/smalltrain .

# %%
import smalltrain as st

# %%
from smalltrain.model.operation import Operation

#  Load trained model using an operation setting file for prediction
setting_file_path = '/var/smalltrain/tutorials/image_recognition/operation/IR_2D_CNN_V2_l49-c64_20210212-small-TRAIN.json'
operation = Operation(setting_file_path=setting_file_path)
operation.auto()

# Get trained model instance
model_ins = operation.model
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1635: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/smalltrain/model/nn_model.py:1775: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/normalization.py:327: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py:1752: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/smalltrain/model/two_dim_cnn_model.py:1321: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/smalltrain/model/two_dim_cnn_model.py:1252: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# <smalltrain.data_set.img_data_set.IMGData object at 0x7f966745bc88>
# [   0    1    2 ... 9997 9998 9999]
# INFO:tensorflow:/var/data/smalltrain/results/model/IR_2D_CNN_V2_l49-c64_TUTORIAL-DEBUG-WITH-SMALLDATASET-20210708-TRAIN/model-nn_lr-0.0001_bs-128.ckpt-49 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:/var/data/smalltrain/results/model/IR_2D_CNN_V2_l49-c64_TUTORIAL-DEBUG-WITH-SMALLDATASET-20210708-TRAIN/model-nn_lr-0.0001_bs-128.ckpt-99 is not in all_model_checkpoint_paths. Manually adding it.
# DONE train data
# ====================

# %%
data = model_ins.data_set.df_data_set_def
data = data[data['test']==0]

# %%
data
# Out:
#       index                                        data_set_id  label  \
# 1100   1100  /var/data/cifar-100-image-fine/train/train_i6_...     90
# 1101   1101  /var/data/cifar-100-image-fine/train/train_i11...     96
# 1102   1102  /var/data/cifar-100-image-fine/train/train_i17...     97
# 1103   1103  /var/data/cifar-100-image-fine/train/train_i43...     97
# 1104   1104  /var/data/cifar-100-image-fine/train/train_i47...     90
# 1105   1105  /var/data/cifar-100-image-fine/train/train_i53...      9
# 1106   1106  /var/data/cifar-100-image-fine/train/train_i58...     98
# 1107   1107  /var/data/cifar-100-image-fine/train/train_i70...     92
# 1108   1108  /var/data/cifar-100-image-fine/train/train_i94...     95
# 1109   1109  /var/data/cifar-100-image-fine/train/train_i97...     99
# 1110   1110  /var/data/cifar-100-image-fine/train/train_i99...     93
# 1111   1111  /var/data/cifar-100-image-fine/train/train_i10...     97
# 1112   1112  /var/data/cifar-100-image-fine/train/train_i10...     93
# 1113   1113  /var/data/cifar-100-image-fine/train/train_i11...     94
# 1114   1114  /var/data/cifar-100-image-fine/train/train_i13...     96
# 1115   1115  /var/data/cifar-100-image-fine/train/train_i14...     99
# 1116   1116  /var/data/cifar-100-image-fine/train/train_i15...     95
# 1117   1117  /var/data/cifar-100-image-fine/train/train_i18...     98
# 1118   1118  /var/data/cifar-100-image-fine/train/train_i19...     94
# 1119   1119  /var/data/cifar-100-image-fine/train/train_i22...      9
# 1120   1120  /var/data/cifar-100-image-fine/train/train_i23...     90
# 1121   1121  /var/data/cifar-100-image-fine/train/train_i23...     90
# 1122   1122  /var/data/cifar-100-image-fine/train/train_i24...     96
# 1123   1123  /var/data/cifar-100-image-fine/train/train_i26...     95
# 1124   1124  /var/data/cifar-100-image-fine/train/train_i27...     90
# 1125   1125  /var/data/cifar-100-image-fine/train/train_i30...     99
# 1126   1126  /var/data/cifar-100-image-fine/train/train_i30...     97
# 1127   1127  /var/data/cifar-100-image-fine/train/train_i31...     97
# 1128   1128  /var/data/cifar-100-image-fine/train/train_i31...     91
# 1129   1129  /var/data/cifar-100-image-fine/train/train_i32...     98
# ...     ...                                                ...    ...
# 6570   6570  /var/data/cifar-100-image-fine/train/train_i49...     98
# 6571   6571  /var/data/cifar-100-image-fine/train/train_i49...      9
# 6572   6572  /var/data/cifar-100-image-fine/train/train_i49...     94
# 6573   6573  /var/data/cifar-100-image-fine/train/train_i49...     91
# 6574   6574  /var/data/cifar-100-image-fine/train/train_i49...     96
# 6575   6575  /var/data/cifar-100-image-fine/train/train_i49...     91
# 6576   6576  /var/data/cifar-100-image-fine/train/train_i49...     98
# 6577   6577  /var/data/cifar-100-image-fine/train/train_i49...     93
# 6578   6578  /var/data/cifar-100-image-fine/train/train_i49...     94
# 6579   6579  /var/data/cifar-100-image-fine/train/train_i49...     94
# 6580   6580  /var/data/cifar-100-image-fine/train/train_i49...     96
# 6581   6581  /var/data/cifar-100-image-fine/train/train_i49...     98
# 6582   6582  /var/data/cifar-100-image-fine/train/train_i49...     96
# 6583   6583  /var/data/cifar-100-image-fine/train/train_i49...     99
# 6584   6584  /var/data/cifar-100-image-fine/train/train_i49...     96
# 6585   6585  /var/data/cifar-100-image-fine/train/train_i49...     99
# 6586   6586  /var/data/cifar-100-image-fine/train/train_i49...     91
# 6587   6587  /var/data/cifar-100-image-fine/train/train_i49...     91
# 6588   6588  /var/data/cifar-100-image-fine/train/train_i49...      9
# 6589   6589  /var/data/cifar-100-image-fine/train/train_i49...     94
# 6590   6590  /var/data/cifar-100-image-fine/train/train_i49...     98
# 6591   6591  /var/data/cifar-100-image-fine/train/train_i49...      9
# 6592   6592  /var/data/cifar-100-image-fine/train/train_i49...     90
# 6593   6593  /var/data/cifar-100-image-fine/train/train_i49...     90
# 6594   6594  /var/data/cifar-100-image-fine/train/train_i49...     99
# 6595   6595  /var/data/cifar-100-image-fine/train/train_i49...     93
# 6596   6596  /var/data/cifar-100-image-fine/train/train_i49...     90
# 6597   6597  /var/data/cifar-100-image-fine/train/train_i49...     96
# 6598   6598  /var/data/cifar-100-image-fine/train/train_i49...     94
# 6599   6599  /var/data/cifar-100-image-fine/train/train_i49...     97
#
#       sub_label  test  group file_path
# 1100         90     0  TRAIN       NaN
# 1101         96     0  TRAIN       NaN
# 1102         97     0  TRAIN       NaN
# 1103         97     0  TRAIN       NaN
# 1104         90     0  TRAIN       NaN
# 1105          9     0  TRAIN       NaN
# 1106         98     0  TRAIN       NaN
# 1107         92     0  TRAIN       NaN
# 1108         95     0  TRAIN       NaN
# 1109         99     0  TRAIN       NaN
# 1110         93     0  TRAIN       NaN
# 1111         97     0  TRAIN       NaN
# 1112         93     0  TRAIN       NaN
# 1113         94     0  TRAIN       NaN
# 1114         96     0  TRAIN       NaN
# 1115         99     0  TRAIN       NaN
# 1116         95     0  TRAIN       NaN
# 1117         98     0  TRAIN       NaN
# 1118         94     0  TRAIN       NaN
# 1119          9     0  TRAIN       NaN
# 1120         90     0  TRAIN       NaN
# 1121         90     0  TRAIN       NaN
# 1122         96     0  TRAIN       NaN
# 1123         95     0  TRAIN       NaN
# 1124         90     0  TRAIN       NaN
# 1125         99     0  TRAIN       NaN
# 1126         97     0  TRAIN       NaN
# 1127         97     0  TRAIN       NaN
# 1128         91     0  TRAIN       NaN
# 1129         98     0  TRAIN       NaN
# ...         ...   ...    ...       ...
# 6570         98     0  TRAIN       NaN
# 6571          9     0  TRAIN       NaN
# 6572         94     0  TRAIN       NaN
# 6573         91     0  TRAIN       NaN
# 6574         96     0  TRAIN       NaN
# 6575         91     0  TRAIN       NaN
# 6576         98     0  TRAIN       NaN
# 6577         93     0  TRAIN       NaN
# 6578         94     0  TRAIN       NaN
# 6579         94     0  TRAIN       NaN
# 6580         96     0  TRAIN       NaN
# 6581         98     0  TRAIN       NaN
# 6582         96     0  TRAIN       NaN
# 6583         99     0  TRAIN       NaN
# 6584         96     0  TRAIN       NaN
# 6585         99     0  TRAIN       NaN
# 6586         91     0  TRAIN       NaN
# 6587         91     0  TRAIN       NaN
# 6588          9     0  TRAIN       NaN
# 6589         94     0  TRAIN       NaN
# 6590         98     0  TRAIN       NaN
# 6591          9     0  TRAIN       NaN
# 6592         90     0  TRAIN       NaN
# 6593         90     0  TRAIN       NaN
# 6594         99     0  TRAIN       NaN
# 6595         93     0  TRAIN       NaN
# 6596         90     0  TRAIN       NaN
# 6597         96     0  TRAIN       NaN
# 6598         94     0  TRAIN       NaN
# 6599         97     0  TRAIN       NaN
#
# [5500 rows x 7 columns]

# %%
# Load other libraries
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# Prepare CIFAR-10 label name dictionary to convert label to label name

label_name_dict = {
    0: "beaver",
    1: "dolphin",
    2: "otter",
    3: "seal",
    4: "whale",
    5: "aquarium fish",
    6: "flatfish",
    7: "ray",
    8: "shark",
    9: "trout",
    10: "orchids",
    11: "poppies",
    12: "roses",
    13: "sunflowers",
    14: "tulips",
    15: "bottles",
    16: "bowls",
    17: "cans",
    18: "cups",
    19: "plates",
    20: "apples",
    21: "mushrooms",
    22: "oranges",
    23: "pears",
    24: "sweet peppers",
    25: "clock",
    26: "computer keyboard",
    27: "lamp",
    28: "telephone",
    29: "television",
    30: "bed",
    31: "chair",
    32: "couch",
    33: "table",
    34: "wardrobe",
    35: "bee",
    36: "beetle",
    37: "butterfly",
    38: "caterpillar",
    39: "cockroach",
    40: "bear",
    41: "leopard",
    42: "lion",
    43: "tiger",
    44: "wolf",
    45: "bridge",
    46: "castle",
    47: "house",
    48: "road",
    49: "skyscraper",
    50: "cloud",
    51: "forest",
    52: "mountain",
    53: "plain",
    54: "sea",
    55: "camel",
    56: "cattle",
    57: "chimpanzee",
    58: "elephant",
    59: "kangaroo",
    60: "fox",
    61: "porcupine",
    62: "possum",
    63: "raccoon",
    64: "skunk",
    65: "crab",
    66: "lobster",
    67: "snail",
    68: "spider",
    69: "worm",
    70: "baby",
    71: "boy",
    72: "girl",
    73: "man",
    74: "woman",
    75: "crocodile",
    76: "dinosaur",
    77: "lizard",
    78: "snake",
    79: "turtle",
    80: "hamster",
    81: "mouse",
    82: "rabbit",
    83: "shrew",
    84: "squirrel",
    85: "maple",
    86: "oak",
    87: "palm",
    88: "pine",
    89: "willow",
    90: "bicycle",
    91: "bus",
    92: "motorcycle",
    93: "pickup truck",
    94: "train",
    95: "lawn-mower",
    96: "rocket",
    97: "streetcar",
    98: "tank",
    99: "tractor",
    }

print(label_name_dict)

# %%
# Testing the model prediction for 1 input data

# Using a dog image in CIFAR-10 test images
img_file_path = data['data_set_id'][6590]
raw_img = cv2.imread(img_file_path)
plt.imshow(raw_img)

test_img_batch = np.asarray([raw_img])
print('test_img_batch shape: {}'.format(test_img_batch.shape))
# Out:
# test_img_batch shape: (1, 32, 32, 3)

# %%
result_dist = model_ins.sess.run(
    [model_ins.y], feed_dict={model_ins.x: test_img_batch,
                             model_ins.is_train:False,
                             model_ins.keep_prob:1}  
)

# %%
# Check the output of  the model
result_dist = result_dist[0][0]
label = np.argmax(result_dist)
print('Predicted output as label: {}'.format(label))
# Out:
# Predicted output as label: 0

# %% [markdown]
# ## For multiple images

# %%
plt.figure(figsize=(100, 100)).set_size_inches(100, 100)

#subplot(r,c) provide the no. of rows and columns

values = 2
f, axarr = plt.subplots(1, values) 

test_input_data = []
for i in range(values):
    img_file_path = data['data_set_id'][i]
    raw_img = cv2.imread(img_file_path)
    axarr[i].imshow(raw_img)
    test_input_data.append(raw_img)
test_img_batch = np.asarray(test_input_data)
print('test_img_batch shape: {}'.format(test_img_batch.shape))
# Out:
# test_img_batch shape: (2, 32, 32, 3)

# %%
# Predict for the a dog image

result_dist = model_ins.sess.run(
    [model_ins.y], feed_dict={model_ins.x: test_img_batch,
                             model_ins.is_train:False,
                             model_ins.keep_prob:1}  
)

# %%
# Check the output of  the model

result_dist = result_dist[0]
for result in result_dist:
    label = np.argmax(result)
    print('Predicted output as label: {}'.format(label))
# Out:
# Predicted output as label: 9
# Predicted output as label: 9

# %%
# Out:
# {0: 'beaver', 1: 'dolphin', 2: 'otter', 3: 'seal', 4: 'whale', 5: 'aquarium fish', 6: 'flatfish', 7: 'ray', 8: 'shark', 9: 'trout', 10: 'orchids', 11: 'poppies', 12: 'roses', 13: 'sunflowers', 14: 'tulips', 15: 'bottles', 16: 'bowls', 17: 'cans', 18: 'cups', 19: 'plates', 20: 'apples', 21: 'mushrooms', 22: 'oranges', 23: 'pears', 24: 'sweet peppers', 25: 'clock', 26: 'computer keyboard', 27: 'lamp', 28: 'telephone', 29: 'television', 30: 'bed', 31: 'chair', 32: 'couch', 33: 'table', 34: 'wardrobe', 35: 'bee', 36: 'beetle', 37: 'butterfly', 38: 'caterpillar', 39: 'cockroach', 40: 'bear', 41: 'leopard', 42: 'lion', 43: 'tiger', 44: 'wolf', 45: 'bridge', 46: 'castle', 47: 'house', 48: 'road', 49: 'skyscraper', 50: 'cloud', 51: 'forest', 52: 'mountain', 53: 'plain', 54: 'sea', 55: 'camel', 56: 'cattle', 57: 'chimpanzee', 58: 'elephant', 59: 'kangaroo', 60: 'fox', 61: 'porcupine', 62: 'possum', 63: 'raccoon', 64: 'skunk', 65: 'crab', 66: 'lobster', 67: 'snail', 68: 'spider', 69: 'worm', 70: 'baby', 71: 'boy', 72: 'girl', 73: 'man', 74: 'woman', 75: 'crocodile', 76: 'dinosaur', 77: 'lizard', 78: 'snake', 79: 'turtle', 80: 'hamster', 81: 'mouse', 82: 'rabbit', 83: 'shrew', 84: 'squirrel', 85: 'maple', 86: 'oak', 87: 'palm', 88: 'pine', 89: 'willow', 90: 'bicycle', 91: 'bus', 92: 'motorcycle', 93: 'pickup truck', 94: 'train', 95: 'lawn-mower', 96: 'rocket', 97: 'streetcar', 98: 'tank', 99: 'tractor'}

# %%
# Check the predicted label name
print('Predicted output as label: {}, name: {}'.format(label, label_name_dict[label]))
# Out:
# Predicted output as label: 0, name: beaver

# %%
# Check the predicted distribution
log_result_dist = [math.exp(x) for x in result_dist]
print('Predicted distribution: {}'.format(log_result_dist))
plt.bar(list(label_name_dict.values()), log_result_dist)
plt.xticks(rotation=30)
# Out:
# Predicted distribution: [2745725.2382270303, 0.00017377798705979218, 7.411436941033392, 0.4986746315413544, 206093.6367288055, 1.4624994886507816, 7.290401906922556, 3.1249651525517472, 0.00012315103399973494, 125294.6381003276, 8805.558650515508, 0.002640189905817118, 1.9280235508006036e-05, 44.87836335346604, 1.774617724789143, 594786.9296597344, 0.009600717769770374, 0.6445832551351396, 0.00019099397756290555, 0.03811912857164546]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-e70b4f28fcaa> in <module>
#       2 log_result_dist = [math.exp(x) for x in result_dist]
#       3 print('Predicted distribution: {}'.format(log_result_dist))
# ----> 4 plt.bar(list(label_name_dict.values()), log_result_dist)
#       5 plt.xticks(rotation=30)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2455     return gca().bar(
#    2456         x, height, width=width, bottom=bottom, align=align,
# -> 2457         **({"data": data} if data is not None else {}), **kwargs)
#    2458
#    2459
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2249         x, height, width, y, linewidth = np.broadcast_arrays(
#    2250             # Make args iterable too.
# -> 2251             np.atleast_1d(x), height, width, y, linewidth)
#    2252
#    2253         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
# --> 264     shape = _broadcast_shape(*args)
#     265
#     266     if all(array.shape == shape for array in args):
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     189     # use the old-iterator because np.nditer does not handle size 0 arrays
#     190     # consistently
# --> 191     b = np.broadcast(*args[:32])
#     192     # unfortunately, it cannot handle 32 or more arguments directly
#     193     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
