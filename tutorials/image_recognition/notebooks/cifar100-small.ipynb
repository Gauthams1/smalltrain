# %%
# This is SmallTrain v0.2.1 Demo for image detection
# You can get v0.2.1 on https://github.com/geek-guild/smalltrain .

# %% [markdown]
# import smalltrain as st

# %%
from smalltrain.model.operation import Operation

#  Load trained model using an operation setting file for prediction
setting_file_path = '/var/smalltrain/tutorials/image_recognition/operation/IR_2D_CNN_V2_l49-c64_20210210-TRAIN.json'
operation = Operation(setting_file_path=setting_file_path)
operation.auto()

# Get trained model instance
model_ins = operation.model
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py:1752: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1635: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/smalltrain/model/nn_model.py:1775: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.BatchNormalization` documentation).
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/normalization.py:327: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/smalltrain/model/two_dim_cnn_model.py:1321: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/smalltrain/model/two_dim_cnn_model.py:1252: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# <smalltrain.data_set.img_data_set.IMGData object at 0x7fd2485cecc0>
# [ 998  999 1000 1001 1002 1003]
# INFO:tensorflow:/var/data/smalltrain/results/model/IR_2D_CNN_V2_l49-c64_TUTORIAL-DEBUG-WITH-SMALLDATASET-20200708-TRAIN/model-nn_lr-0.0001_bs-128.ckpt-49 is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:/var/data/smalltrain/results/model/IR_2D_CNN_V2_l49-c64_TUTORIAL-DEBUG-WITH-SMALLDATASET-20200708-TRAIN/model-nn_lr-0.0001_bs-128.ckpt-99 is not in all_model_checkpoint_paths. Manually adding it.
# DONE train data
# ====================

# %%
data = model_ins.data_set.df_data_set_def
data = data[data['test']==0]

# %%
data
# Out:
#       index                                        data_set_id  label  \
# 500     500   /var/data/cifar-100-image/train/train_i13_c9.png      9
# 501     501   /var/data/cifar-100-image/train/train_i31_c9.png      9
# 502     502   /var/data/cifar-100-image/train/train_i45_c9.png      9
# 503     503  /var/data/cifar-100-image/train/train_i116_c9.png      9
# 504     504  /var/data/cifar-100-image/train/train_i138_c9.png      9
# 505     505  /var/data/cifar-100-image/train/train_i179_c9.png      9
# 506     506  /var/data/cifar-100-image/train/train_i193_c9.png      9
# 507     507  /var/data/cifar-100-image/train/train_i209_c9.png      9
# 508     508  /var/data/cifar-100-image/train/train_i212_c9.png      9
# 509     509  /var/data/cifar-100-image/train/train_i217_c9.png      9
# 510     510  /var/data/cifar-100-image/train/train_i279_c9.png      9
# 511     511  /var/data/cifar-100-image/train/train_i294_c9.png      9
# 512     512  /var/data/cifar-100-image/train/train_i320_c9.png      9
# 513     513  /var/data/cifar-100-image/train/train_i339_c9.png      9
# 514     514  /var/data/cifar-100-image/train/train_i345_c9.png      9
# 515     515  /var/data/cifar-100-image/train/train_i358_c9.png      9
# 516     516  /var/data/cifar-100-image/train/train_i371_c9.png      9
# 517     517  /var/data/cifar-100-image/train/train_i415_c9.png      9
# 518     518  /var/data/cifar-100-image/train/train_i431_c9.png      9
# 519     519  /var/data/cifar-100-image/train/train_i454_c9.png      9
# 520     520  /var/data/cifar-100-image/train/train_i506_c9.png      9
# 521     521  /var/data/cifar-100-image/train/train_i522_c9.png      9
# 522     522  /var/data/cifar-100-image/train/train_i566_c9.png      9
# 523     523  /var/data/cifar-100-image/train/train_i588_c9.png      9
# 524     524  /var/data/cifar-100-image/train/train_i605_c9.png      9
# 525     525  /var/data/cifar-100-image/train/train_i608_c9.png      9
# 526     526  /var/data/cifar-100-image/train/train_i624_c9.png      9
# 527     527  /var/data/cifar-100-image/train/train_i693_c9.png      9
# 528     528  /var/data/cifar-100-image/train/train_i696_c9.png      9
# 529     529  /var/data/cifar-100-image/train/train_i700_c9.png      9
# ...     ...                                                ...    ...
# 2970   2970  /var/data/cifar-100-image/train/train_i49369_c...      9
# 2971   2971  /var/data/cifar-100-image/train/train_i49395_c...      9
# 2972   2972  /var/data/cifar-100-image/train/train_i49403_c...      9
# 2973   2973  /var/data/cifar-100-image/train/train_i49421_c...      9
# 2974   2974  /var/data/cifar-100-image/train/train_i49443_c...      9
# 2975   2975  /var/data/cifar-100-image/train/train_i49464_c...      9
# 2976   2976  /var/data/cifar-100-image/train/train_i49491_c...      9
# 2977   2977  /var/data/cifar-100-image/train/train_i49534_c...      9
# 2978   2978  /var/data/cifar-100-image/train/train_i49538_c...      9
# 2979   2979  /var/data/cifar-100-image/train/train_i49555_c...      9
# 2980   2980  /var/data/cifar-100-image/train/train_i49556_c...      9
# 2981   2981  /var/data/cifar-100-image/train/train_i49563_c...      9
# 2982   2982  /var/data/cifar-100-image/train/train_i49606_c...      9
# 2983   2983  /var/data/cifar-100-image/train/train_i49634_c...      9
# 2984   2984  /var/data/cifar-100-image/train/train_i49639_c...      9
# 2985   2985  /var/data/cifar-100-image/train/train_i49696_c...      9
# 2986   2986  /var/data/cifar-100-image/train/train_i49728_c...      9
# 2987   2987  /var/data/cifar-100-image/train/train_i49740_c...      9
# 2988   2988  /var/data/cifar-100-image/train/train_i49767_c...      9
# 2989   2989  /var/data/cifar-100-image/train/train_i49775_c...      9
# 2990   2990  /var/data/cifar-100-image/train/train_i49799_c...      9
# 2991   2991  /var/data/cifar-100-image/train/train_i49809_c...      9
# 2992   2992  /var/data/cifar-100-image/train/train_i49810_c...      9
# 2993   2993  /var/data/cifar-100-image/train/train_i49828_c...      9
# 2994   2994  /var/data/cifar-100-image/train/train_i49891_c...      9
# 2995   2995  /var/data/cifar-100-image/train/train_i49894_c...      9
# 2996   2996  /var/data/cifar-100-image/train/train_i49926_c...      9
# 2997   2997  /var/data/cifar-100-image/train/train_i49932_c...      9
# 2998   2998  /var/data/cifar-100-image/train/train_i49977_c...      9
# 2999   2999  /var/data/cifar-100-image/train/train_i49981_c...      9
#
#       sub_label  test  group  \
# 500           9     0  TRAIN
# 501           9     0  TRAIN
# 502           9     0  TRAIN
# 503           9     0  TRAIN
# 504           9     0  TRAIN
# 505           9     0  TRAIN
# 506           9     0  TRAIN
# 507           9     0  TRAIN
# 508           9     0  TRAIN
# 509           9     0  TRAIN
# 510           9     0  TRAIN
# 511           9     0  TRAIN
# 512           9     0  TRAIN
# 513           9     0  TRAIN
# 514           9     0  TRAIN
# 515           9     0  TRAIN
# 516           9     0  TRAIN
# 517           9     0  TRAIN
# 518           9     0  TRAIN
# 519           9     0  TRAIN
# 520           9     0  TRAIN
# 521           9     0  TRAIN
# 522           9     0  TRAIN
# 523           9     0  TRAIN
# 524           9     0  TRAIN
# 525           9     0  TRAIN
# 526           9     0  TRAIN
# 527           9     0  TRAIN
# 528           9     0  TRAIN
# 529           9     0  TRAIN
# ...         ...   ...    ...
# 2970          9     0  TRAIN
# 2971          9     0  TRAIN
# 2972          9     0  TRAIN
# 2973          9     0  TRAIN
# 2974          9     0  TRAIN
# 2975          9     0  TRAIN
# 2976          9     0  TRAIN
# 2977          9     0  TRAIN
# 2978          9     0  TRAIN
# 2979          9     0  TRAIN
# 2980          9     0  TRAIN
# 2981          9     0  TRAIN
# 2982          9     0  TRAIN
# 2983          9     0  TRAIN
# 2984          9     0  TRAIN
# 2985          9     0  TRAIN
# 2986          9     0  TRAIN
# 2987          9     0  TRAIN
# 2988          9     0  TRAIN
# 2989          9     0  TRAIN
# 2990          9     0  TRAIN
# 2991          9     0  TRAIN
# 2992          9     0  TRAIN
# 2993          9     0  TRAIN
# 2994          9     0  TRAIN
# 2995          9     0  TRAIN
# 2996          9     0  TRAIN
# 2997          9     0  TRAIN
# 2998          9     0  TRAIN
# 2999          9     0  TRAIN
#
#                                               file_path
# 500    /var/data/cifar-100-image/train/train_i13_c9.png
# 501    /var/data/cifar-100-image/train/train_i31_c9.png
# 502    /var/data/cifar-100-image/train/train_i45_c9.png
# 503   /var/data/cifar-100-image/train/train_i116_c9.png
# 504   /var/data/cifar-100-image/train/train_i138_c9.png
# 505   /var/data/cifar-100-image/train/train_i179_c9.png
# 506   /var/data/cifar-100-image/train/train_i193_c9.png
# 507   /var/data/cifar-100-image/train/train_i209_c9.png
# 508   /var/data/cifar-100-image/train/train_i212_c9.png
# 509   /var/data/cifar-100-image/train/train_i217_c9.png
# 510   /var/data/cifar-100-image/train/train_i279_c9.png
# 511   /var/data/cifar-100-image/train/train_i294_c9.png
# 512   /var/data/cifar-100-image/train/train_i320_c9.png
# 513   /var/data/cifar-100-image/train/train_i339_c9.png
# 514   /var/data/cifar-100-image/train/train_i345_c9.png
# 515   /var/data/cifar-100-image/train/train_i358_c9.png
# 516   /var/data/cifar-100-image/train/train_i371_c9.png
# 517   /var/data/cifar-100-image/train/train_i415_c9.png
# 518   /var/data/cifar-100-image/train/train_i431_c9.png
# 519   /var/data/cifar-100-image/train/train_i454_c9.png
# 520   /var/data/cifar-100-image/train/train_i506_c9.png
# 521   /var/data/cifar-100-image/train/train_i522_c9.png
# 522   /var/data/cifar-100-image/train/train_i566_c9.png
# 523   /var/data/cifar-100-image/train/train_i588_c9.png
# 524   /var/data/cifar-100-image/train/train_i605_c9.png
# 525   /var/data/cifar-100-image/train/train_i608_c9.png
# 526   /var/data/cifar-100-image/train/train_i624_c9.png
# 527   /var/data/cifar-100-image/train/train_i693_c9.png
# 528   /var/data/cifar-100-image/train/train_i696_c9.png
# 529   /var/data/cifar-100-image/train/train_i700_c9.png
# ...                                                 ...
# 2970  /var/data/cifar-100-image/train/train_i49369_c...
# 2971  /var/data/cifar-100-image/train/train_i49395_c...
# 2972  /var/data/cifar-100-image/train/train_i49403_c...
# 2973  /var/data/cifar-100-image/train/train_i49421_c...
# 2974  /var/data/cifar-100-image/train/train_i49443_c...
# 2975  /var/data/cifar-100-image/train/train_i49464_c...
# 2976  /var/data/cifar-100-image/train/train_i49491_c...
# 2977  /var/data/cifar-100-image/train/train_i49534_c...
# 2978  /var/data/cifar-100-image/train/train_i49538_c...
# 2979  /var/data/cifar-100-image/train/train_i49555_c...
# 2980  /var/data/cifar-100-image/train/train_i49556_c...
# 2981  /var/data/cifar-100-image/train/train_i49563_c...
# 2982  /var/data/cifar-100-image/train/train_i49606_c...
# 2983  /var/data/cifar-100-image/train/train_i49634_c...
# 2984  /var/data/cifar-100-image/train/train_i49639_c...
# 2985  /var/data/cifar-100-image/train/train_i49696_c...
# 2986  /var/data/cifar-100-image/train/train_i49728_c...
# 2987  /var/data/cifar-100-image/train/train_i49740_c...
# 2988  /var/data/cifar-100-image/train/train_i49767_c...
# 2989  /var/data/cifar-100-image/train/train_i49775_c...
# 2990  /var/data/cifar-100-image/train/train_i49799_c...
# 2991  /var/data/cifar-100-image/train/train_i49809_c...
# 2992  /var/data/cifar-100-image/train/train_i49810_c...
# 2993  /var/data/cifar-100-image/train/train_i49828_c...
# 2994  /var/data/cifar-100-image/train/train_i49891_c...
# 2995  /var/data/cifar-100-image/train/train_i49894_c...
# 2996  /var/data/cifar-100-image/train/train_i49926_c...
# 2997  /var/data/cifar-100-image/train/train_i49932_c...
# 2998  /var/data/cifar-100-image/train/train_i49977_c...
# 2999  /var/data/cifar-100-image/train/train_i49981_c...
#
# [2500 rows x 7 columns]

# %%
# Load other libraries
import tensorflow.compat.v1 as tf
tf.disable_eager_execution()

import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
data['data_set_id']
# Out:
# 500      /var/data/cifar-100-image/train/train_i13_c9.png
# 501      /var/data/cifar-100-image/train/train_i31_c9.png
# 502      /var/data/cifar-100-image/train/train_i45_c9.png
# 503     /var/data/cifar-100-image/train/train_i116_c9.png
# 504     /var/data/cifar-100-image/train/train_i138_c9.png
# 505     /var/data/cifar-100-image/train/train_i179_c9.png
# 506     /var/data/cifar-100-image/train/train_i193_c9.png
# 507     /var/data/cifar-100-image/train/train_i209_c9.png
# 508     /var/data/cifar-100-image/train/train_i212_c9.png
# 509     /var/data/cifar-100-image/train/train_i217_c9.png
# 510     /var/data/cifar-100-image/train/train_i279_c9.png
# 511     /var/data/cifar-100-image/train/train_i294_c9.png
# 512     /var/data/cifar-100-image/train/train_i320_c9.png
# 513     /var/data/cifar-100-image/train/train_i339_c9.png
# 514     /var/data/cifar-100-image/train/train_i345_c9.png
# 515     /var/data/cifar-100-image/train/train_i358_c9.png
# 516     /var/data/cifar-100-image/train/train_i371_c9.png
# 517     /var/data/cifar-100-image/train/train_i415_c9.png
# 518     /var/data/cifar-100-image/train/train_i431_c9.png
# 519     /var/data/cifar-100-image/train/train_i454_c9.png
# 520     /var/data/cifar-100-image/train/train_i506_c9.png
# 521     /var/data/cifar-100-image/train/train_i522_c9.png
# 522     /var/data/cifar-100-image/train/train_i566_c9.png
# 523     /var/data/cifar-100-image/train/train_i588_c9.png
# 524     /var/data/cifar-100-image/train/train_i605_c9.png
# 525     /var/data/cifar-100-image/train/train_i608_c9.png
# 526     /var/data/cifar-100-image/train/train_i624_c9.png
# 527     /var/data/cifar-100-image/train/train_i693_c9.png
# 528     /var/data/cifar-100-image/train/train_i696_c9.png
# 529     /var/data/cifar-100-image/train/train_i700_c9.png
#                               ...
# 2970    /var/data/cifar-100-image/train/train_i49369_c...
# 2971    /var/data/cifar-100-image/train/train_i49395_c...
# 2972    /var/data/cifar-100-image/train/train_i49403_c...
# 2973    /var/data/cifar-100-image/train/train_i49421_c...
# 2974    /var/data/cifar-100-image/train/train_i49443_c...
# 2975    /var/data/cifar-100-image/train/train_i49464_c...
# 2976    /var/data/cifar-100-image/train/train_i49491_c...
# 2977    /var/data/cifar-100-image/train/train_i49534_c...
# 2978    /var/data/cifar-100-image/train/train_i49538_c...
# 2979    /var/data/cifar-100-image/train/train_i49555_c...
# 2980    /var/data/cifar-100-image/train/train_i49556_c...
# 2981    /var/data/cifar-100-image/train/train_i49563_c...
# 2982    /var/data/cifar-100-image/train/train_i49606_c...
# 2983    /var/data/cifar-100-image/train/train_i49634_c...
# 2984    /var/data/cifar-100-image/train/train_i49639_c...
# 2985    /var/data/cifar-100-image/train/train_i49696_c...
# 2986    /var/data/cifar-100-image/train/train_i49728_c...
# 2987    /var/data/cifar-100-image/train/train_i49740_c...
# 2988    /var/data/cifar-100-image/train/train_i49767_c...
# 2989    /var/data/cifar-100-image/train/train_i49775_c...
# 2990    /var/data/cifar-100-image/train/train_i49799_c...
# 2991    /var/data/cifar-100-image/train/train_i49809_c...
# 2992    /var/data/cifar-100-image/train/train_i49810_c...
# 2993    /var/data/cifar-100-image/train/train_i49828_c...
# 2994    /var/data/cifar-100-image/train/train_i49891_c...
# 2995    /var/data/cifar-100-image/train/train_i49894_c...
# 2996    /var/data/cifar-100-image/train/train_i49926_c...
# 2997    /var/data/cifar-100-image/train/train_i49932_c...
# 2998    /var/data/cifar-100-image/train/train_i49977_c...
# 2999    /var/data/cifar-100-image/train/train_i49981_c...
# Name: data_set_id, Length: 2500, dtype: object

# %%
# Testing the model prediction for 1 input data

# Using a dog image in CIFAR-10 test images
img_file_path = data['data_set_id'][2980]
raw_img = cv2.imread(img_file_path)
plt.imshow(raw_img)

test_img_batch = np.asarray([raw_img])
print('test_img_batch shape: {}'.format(test_img_batch.shape))
# Out:
# test_img_batch shape: (1, 32, 32, 3)

# %%
result_dist = model_ins.sess.run(
    [model_ins.y], feed_dict={model_ins.x: test_img_batch,
                             model_ins.is_train:False,
                             model_ins.keep_prob:1}  
)

# %%
plt.figure(figsize=(100, 100)).set_size_inches(100, 100)

#subplot(r,c) provide the no. of rows and columns

values = 2
f, axarr = plt.subplots(1, values) 

test_input_data = []
for i in range(values):
    img_file_path = data['data_set_id'][i]
    raw_img = cv2.imread(img_file_path)
    axarr[i].imshow(raw_img)
    test_input_data.append(raw_img)
test_img_batch = np.asarray(test_input_data)
print('test_img_batch shape: {}'.format(test_img_batch.shape))
# Out:
# test_img_batch shape: (2, 32, 32, 3)

# %%
# Predict for the a dog image

result_dist = model_ins.sess.run(
    [model_ins.y], feed_dict={model_ins.x: test_img_batch,
                             model_ins.is_train:False,
                             model_ins.keep_prob:1}  
)

# %%
# Check the output of  the model

result_dist = result_dist[0]
for result in result_dist:
    label = np.argmax(result)
    print('Predicted output as label: {}'.format(label))
# Out:
# Predicted output as label: 9
# Predicted output as label: 9

# %%
# Prepare CIFAR-10 label name dictionary to convert label to label name

label_name_dict = {
    0:"aquatic mammals",
    1:"fish",
    2:"flowers",
    3:"food containers",
    4:"fruit and vegetables",
    5:"household electrical devices",
    6:"household furniture",
    7:"insects",
    8:"large carnivores",
    9:"large man-made outdoor things",
    10:"large natural outdoor scenes",
    11:"large omnivores and herbivores",
    12:"medium-sized mammals",
    13:"non-insect invertebrates",
    14:"people",
    15:"reptiles",
    16:"small mammals",
    17:"trees",
    18:"vehicles 1",
    19:"vehicles 2"
}

print(label_name_dict)
# Out:
# {0: 'aquatic mammals', 1: 'fish', 2: 'flowers', 3: 'food containers', 4: 'fruit and vegetables', 5: 'household electrical devices', 6: 'household furniture', 7: 'insects', 8: 'large carnivores', 9: 'large man-made outdoor things', 10: 'large natural outdoor scenes', 11: 'large omnivores and herbivores', 12: 'medium-sized mammals', 13: 'non-insect invertebrates', 14: 'people', 15: 'reptiles', 16: 'small mammals', 17: 'trees', 18: 'vehicles 1', 19: 'vehicles 2'}

# %%
# Check the predicted label name
print('Predicted output as label: {}, name: {}'.format(label, label_name_dict[label]))
# Out:
# Predicted output as label: 9, name: large man-made outdoor things

# %%
# Check the predicted distribution
log_result_dist = [math.exp(x) for x in result_dist]
print('Predicted distribution: {}'.format(log_result_dist))
plt.bar(list(label_name_dict.values()), log_result_dist)
plt.xticks(rotation=30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-e70b4f28fcaa> in <module>
#       1 # Check the predicted distribution
# ----> 2 log_result_dist = [math.exp(x) for x in result_dist]
#       3 print('Predicted distribution: {}'.format(log_result_dist))
#       4 plt.bar(list(label_name_dict.values()), log_result_dist)
#       5 plt.xticks(rotation=30)
#
# <ipython-input-102-e70b4f28fcaa> in <listcomp>(.0)
#       1 # Check the predicted distribution
# ----> 2 log_result_dist = [math.exp(x) for x in result_dist]
#       3 print('Predicted distribution: {}'.format(log_result_dist))
#       4 plt.bar(list(label_name_dict.values()), log_result_dist)
#       5 plt.xticks(rotation=30)
#
# TypeError: only size-1 arrays can be converted to Python scalars
